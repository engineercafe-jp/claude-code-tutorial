# %% [markdown]
# # 🤖 Claude Code Tutorial
#
# ## Let's Code with AI!
#
# **Target audience:** Beginner to intermediate programmers
#
# ---
#
# In this tutorial, you'll learn the basics of Claude Code 🚀

# %% [markdown]
# # 1️⃣ What is Claude Code?
#
# **Claude Code** is an **AI coding assistant** developed by Anthropic 🧠
#
# ---
#
# ## ✨ What can it do?
#
# | Feature | Description |
# |---------|-------------|
# | 💬 Code while you chat | Just give instructions in plain English |
# | 🐛 Bug fixing | Show an error and it finds and fixes the cause |
# | 📖 Code explanation | Explains complex code in simple terms |
# | 🔄 Refactoring | Cleans up and reorganizes your code |
# | 🗂️ File operations | Reads and writes Excel, CSV, PDF, images, and more |
#
# ---
#
# ## 📁 Supported file types
#
# | Type | Examples |
# |------|----------|
# | Spreadsheet | `.xlsx` (Excel), `.csv` |
# | Document | `.pdf`, `.docx` (Word) |
# | Image | `.png`, `.jpg` |
# | Text | `.txt`, `.md`, `.json` |
# | Code | `.py`, `.js`, `.sh`, etc. |
#
# ---
#
# **🎯 Key point:** Claude Code is a CLI tool you run from the terminal

# %% [markdown]
# # 2️⃣ Installing Claude Code
#
# ## 🖱️ GUI Version (Desktop App)
#
# ### Mac / Windows
#
# 1. Download from the official site: [claude.ai/code](https://claude.ai/code)
# 2. Run the installer
# 3. Log in with your Anthropic account
#
# ---
#
# **🎯 Easiest option — no command line needed!**

# %% [markdown]
# ## 🖥️ CLI Version (Command Line)
#
# The **native installer** is recommended — no dependencies, auto-updates included 🎯
#
# ### 🍎 macOS / 🐧 Linux
#
# ```bash
# curl -fsSL https://claude.ai/install.sh | bash
# ```
#
# ### 🪟 Windows (PowerShell)
#
# ```powershell
# irm https://claude.ai/install.ps1 | iex
# ```
#
# > **Prerequisite:** Install [Git for Windows](https://git-scm.com/downloads/win) first
#
# ### Launch (all platforms)
#
# ```bash
# claude
# ```
#
# ---
#
# **💡 Tip:** On first launch, you'll be prompted to log in to your Anthropic account

# %% [markdown]
# ## 🧩 VSCode & Antigravity Extensions
#
# ### VSCode
#
# 1. Open VSCode
# 2. Click the Extensions tab (block icon on the left sidebar)
# 3. Search for `Claude Code`
# 4. Click **Install**
#
# ---
#
# ### Antigravity (JetBrains IDEs)
#
# 1. Open your JetBrains IDE (IntelliJ, PyCharm, etc.)
# 2. Go to **Plugins** → Marketplace and search for `Claude Code`
# 3. Click **Install**
#
# ---
#
# **🎉 All options use the same Claude!**

# %% [markdown]
# # 3️⃣ Let's Make Hello World!
#
# ## 📁 First, create a working directory
#
# **🍎 macOS**
# ```bash
# mkdir hello_world
# cd hello_world
# claude
# ```
#
# **🪟 Windows (PowerShell)**
# ```powershell
# mkdir hello_world
# cd hello_world
# claude
# ```
#
# ---
#
# > 💡 **Key point:** Claude Code uses the **directory where it's launched** as its workspace.
# > Create your directory first, then launch `claude`!

# %% [markdown]
# ## 🐍 Create a Hello World Script
#
# Type this into Claude Code:
#
# ---
#
# ### 🍎 macOS
#
# ```
# Create a bash script that displays Hello World
# ```
#
# → `hello_world.sh` is created 🎉
#
# ---
#
# ### 🪟 Windows
#
# ```
# Create a PowerShell script that displays Hello World
# ```
#
# → `hello_world.ps1` is created 🎉
#
# ---
#
# **💡 Key point:** Just tell it your OS and Claude Code picks the right script!

# %% [markdown]
# ## 🎨 Let's Upgrade to Ascii Art!
#
# Next, type this into Claude Code:
#
# ---
#
# ### 🍎 macOS
#
# ```
# Update it to display Hello World as Ascii Art using figlet
# ```
#
# ---
#
# ### 🪟 Windows
#
# ```
# Update it to display Hello World as Ascii Art
# ```
#
# ---
#
# ### What it looks like ✨
#
# ```
#  _   _      _ _         __        __         _     _ _
# | | | | ___| | | ___    \ \      / /__  _ __| | __| | |
# | |_| |/ _ \ | |/ _ \    \ \ /\ / / _ \| '__| |/ _` | |
# |  _  |  __/ | | (_) |    \ V  V / (_) | |  | | (_| |_|
# |_| |_|\___|_|_|\___/      \_/\_/ \___/|_|  |_|\__,_(_)
# ```
#
# **🎊 Done in one sentence!**

# %% [markdown]
# # 4️⃣ Essential Commands for Beginners (1/2)
#
# ## ⌨️ Keyboard Shortcuts
#
# ### 🔄 Shift + Tab — Switch Modes
#
# Each press cycles through modes:
#
# ```
# Normal Mode → Auto-Accept Mode → Plan Mode → Normal Mode ...
# ```
#
# | Mode | Indicator | Description |
# |------|-----------|-------------|
# | **Normal** | (default) | Standard mode — confirms before making changes |
# | **Auto-Accept** | `⏵⏵ accept edits on` | Approves changes automatically |
# | **Plan** | `⏸ plan mode on` | **Read-only** — planning only, no edits |
#
# ---
#
# **💡 Plan Mode is especially important!** → Details on the next slide

# %% [markdown]
# ## ⌨️ Slash Commands (2/2)
#
# These commands are available at any time during a session:
#
# | Command | Description | When to use |
# |---------|-------------|-------------|
# | `/model` | Change the AI model | Adjust speed vs. accuracy |
# | `/status` | Check current status | See what's going on |
# | `/resume` | Resume a previous session | Continue yesterday's work |
# | `/clear` | Reset conversation history | Switch to a different task |
# | `/init` | Auto-generate CLAUDE.md | When starting a new project |
#
# ---
#
# ### Other Shortcuts
#
# | Shortcut | Description |
# |----------|-------------|
# | `?` | Show keyboard shortcut list |
# | `Esc` | Stop the current action |
# | `Ctrl+C` | Exit Claude Code |

# %% [markdown]
# # 🗺️ What is Plan Mode?
#
# ## Switch with Shift+Tab — Planning-Only Mode
#
# **Plan Mode** = Claude reads files **without making any edits** 🔍
#
# ---
#
# ## 🎯 Why use it?
#
# > **"Plan before you implement!"**
#
# Jumping straight into complex changes can cause:
# - ❌ Unexpected files getting modified
# - ❌ Too much code written to review
# - ❌ Hard-to-undo mistakes
#
# With Plan Mode:
# - ✅ Claude only reads and analyzes
# - ✅ You review the plan before anything is changed
# - ✅ Implementation starts only after you approve
#
# ---
#
# ## 📋 Recommended Workflow
#
# ```
# 1. Explore & plan in Plan Mode 🔍
# 2. Review & approve the plan ✅
# 3. Implement in Normal Mode 💻
# 4. Test & commit 🎉
# ```

# %% [markdown]
# # 5️⃣ Essential Tips for Beginners
#
# ## ✍️ Write Specific Prompts
#
# ### ❌ Bad example
# ```
# Fix the bug
# ```
#
# ### ✅ Good example
# ```
# Fix the bug where the screen goes blank after entering
# a wrong email on the login page and clicking Back
# ```
#
# ---
#
# ## 🧹 Context Management
#
# Claude remembers the conversation history (context) while working.
#
# **Accuracy drops as it gets longer!** → Reset regularly
#
# ```
# Before switching to a new task → /clear
# ```
#
# **🎯 One conversation = one task**

# %% [markdown]
# # 6️⃣ Practice! Get Fukuoka City Weather Forecast 📋
#
# We'll fetch real-time weather forecast data from the Japan Meteorological Agency API.
#
# ---
#
# Tell Claude Code:
#
# ```
# Using the JMA API, create a Python script that fetches
# and displays the weather forecast for Fukuoka City
# ```

# %%
import urllib.request
import json

# Japan Meteorological Agency API: Fukuoka Prefecture (area code 400000)
url = "https://www.jma.go.jp/bosai/forecast/data/forecast/400000.json"

with urllib.request.urlopen(url) as response:
    data = json.loads(response.read())

# Get forecast for Fukuoka area
area_name = data[0]["timeSeries"][0]["areas"][0]["area"]["name"]
weather_codes = data[0]["timeSeries"][0]["areas"][0]["weatherCodes"]
time_defines = data[0]["timeSeries"][0]["timeDefines"]

# Weather code → description
weather_map = {
    "100": "☀️ Sunny",
    "101": "🌤️ Partly Cloudy",
    "200": "☁️ Cloudy",
    "201": "🌥️ Mostly Cloudy",
    "300": "🌧️ Rainy",
    "400": "❄️ Snowy",
}

print(f"📍 Weather Forecast: {area_name}")
print("-" * 30)
for time, code in zip(time_defines[:3], weather_codes[:3]):
    date = time[:10]
    weather = weather_map.get(code, f"Code: {code}")
    print(f"{date}: {weather}")

# %% [markdown]
# # 📎 Appendix: Upload to GitHub
#
# Save and share your files on **GitHub** 🌐
#
# ---
#
# ## What is GitHub?
#
# - A service for storing and publishing code online
# - Used by developers worldwide
# - Free to get started
#
# ---
#
# First, create an account at [github.com](https://github.com)!

# %% [markdown]
# ## 1️⃣ Create a Repository
#
# **Repository** = a folder-like container for managing your files
#
# ---
#
# ### Steps
#
# 1. Log in to [github.com](https://github.com)
# 2. Click **`+`** in the top right → **New repository**
# 3. Fill in the details and click **Create repository**
#
# | Field | Example |
# |-------|---------|
# | Repository name | `hello-world` |
# | Description | Optional |
# | Public / Private | **Public** or Private |
# | Add a README file | ✅ Check this |
#
# ---
#
# **🎉 Your repository is ready!**

# %% [markdown]
# ## 2️⃣ Upload Files
#
# You can upload files right from your browser — like copy & paste!
#
# ---
#
# ### Steps
#
# 1. Open your repository page
# 2. Click **Add file** → **Upload files**
# 3. Drag & drop files, or click **choose your files** to select them
# 4. Click **Commit changes** at the bottom
#
# ---
#
# ### 💡 Tips
#
# - Upload multiple files at once
# - You can drag & drop entire folders
#
# ---
#
# **✅ Your files are now published on GitHub!**

# %% [markdown]
# ## 💻 How Developers Usually Do It: CLI
#
# The browser upload is convenient, but in practice most developers use **git commands**.
#
# ---
#
# ### ⚠️ Setup Required First
#
# Authentication with GitHub is needed before `git push`:
#
# | Method | Difficulty | Overview |
# |--------|------------|----------|
# | **SSH key** | ★★☆ | Generate a key pair and register the public key on GitHub |
# | **GitHub CLI** | ★☆☆ | One command: `gh auth login` |
#
# ---
#
# ### Common Commands (after authentication)
#
# ```bash
# git clone https://github.com/username/repository-name
# git add .
# git commit -m "Initial commit"
# git push
# ```
#
# ---
#
# > 💡 Once you're comfortable, try the CLI approach!
# > Claude Code can run git commands for you too 🤖
